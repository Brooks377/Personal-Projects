# %% [markdown]
# ## This is a practice range for cleaning the data when Mom inputs a .csv file
# - End goal:
#     - Mom inputs a .csv file using drag and drop on streamlit dashboard
#     - Sorts the plants into the categories
#     - Instantly creates a plant list based on the QTY and ID columns
#     - Populates each ID with pictures/captions and creates a word document for easy formatting
#     - exports on streamlit to .docx or pdf or wutever

# %%
import numpy as np
import pandas as pd
import os
from PIL import Image

# %%
pd.set_option('display.max_rows', 100)

# %%
os.getcwd()
# Out:
# 'c:\\Users\\dbawa\\ZZ__School_Related\\z_other\\Code\\Personal_Projects\\FlowerPower\\flower_sandbox'

# %%
df = pd.read_csv("../inputs/user_input/BARTLEY STEWART- Plant list JAN2023 copy for TEST.csv")

# %%
# Set the column names
df.columns = df.iloc[7]

# %%
# grab the name of the project for automatic naming
nameNFMT = df.loc[1, "Common Name"]
projectName = "The "+nameNFMT+" Project"

# Remove the first 5 rows while preserving column names
df = df.iloc[9:, :]
df = df.reset_index(drop=True)

# %%
# Drop all NaN only rows & columns
df = df.dropna(how='all')
df = df.dropna(axis=1, how='all')
df = df.reset_index(drop=True)

# %%
# iterate through the Qty row to get the plant group names and their index values
plant_groups_wIDX = {}
for index, value in df['Qty'].items():
    if not value.isnumeric():
        if value.startswith("ADDED after"):
            addedAfterIndex = index
            break
        else:
            plant_groups_wIDX[value] = index

# %%
# create a dictionary to hold the list of IDs for each group
plant_groups_wID = {key: [] for key in plant_groups_wIDX.keys()}

# converting dict keys into a list for index access
keys_list = list(plant_groups_wIDX.keys())

for i in range(len(keys_list)):
    # if not at the last element in keys_list
    if i != len(keys_list) - 1:
        # take IDs from the index of the current key till the index of the next key
        plant_groups_wID[keys_list[i]] = df['ID'].iloc[plant_groups_wIDX[keys_list[i]] + 1 : plant_groups_wIDX[keys_list[i+1]]].tolist()
    else:
        # for the last key, take IDs till the end of the dataframe
        plant_groups_wID[keys_list[i]] = df['ID'].iloc[plant_groups_wIDX[keys_list[i]] + 1 : addedAfterIndex].tolist()

# %%
df
# Out:
# 7   NaN                                                Qty        ID  \
# 0   NaN                                    Deciduous Trees       NaN
# 1   NaN                                           Conifers       NaN
# 2   NaN                                                  2   CH OB G
# 3   NaN                                                  3  TH PL GG
# 4   NaN                                             Shrubs       NaN
# 5   NaN                                                  1  CO AL IH
# 6     *                                                  2  FO MA MA
# 7     *                                                  1     HA VA
# 8   NaN                                                  6  HY AR IB
# 9   NaN                                                  6  HY PA LI
# 10  NaN                                                  2  HY QU RS
# 11  NaN                                                  1   IL GL C
# 12    *                                                  1   IL GL C
# 13  NaN                                                  2     PI MF
# 14    *                                                  3     PI MF
# 15  NaN                                                  1     PI BB
# 16  NaN                                                  1     RH PW
# 17  NaN                                                  2      RH P
# 18  NaN                                                  3  RH MA RO
# 19  NaN                                                  3   VI PL S
# 20  NaN                                                  5   VI TR W
# 21  NaN                                         Perennials       NaN
# 22  NaN                                                  5     Act B
# 23  N/C                                                  1     Dia M
# 24  NaN                                                  4    Ast VD
# 25  NaN                                                  6    Bru JF
# 26  NaN                                                  6     Dic e
# 27  NaN                                                  6     Ger R
# 28  NaN                                                  4     Hel B
# 29  NaN                                                  2     Hos G
# 30  NaN                                                  2    Hos BA
# 31  NaN                                                  5     Iri I
# 32  NaN                                                  4    Nep PB
# 33  NaN                                                  2    Pae IB
# 34  NaN                                                 10     Sed D
# 35  NaN                                                  5    Tia RT
# 36  NaN                                              FERNS       NaN
# 37  NaN                                                  9     Dry B
# 38  NaN                                 Ornamental Grasses       NaN
# 39  NaN                                                  3    Cal KF
# 40  NaN                                                  3  Pen LB-1
# 41    *        ADDED after budgeted plant list per request       NaN
# 42  NaN  Existing Trees/Shrubs/Perennials for Transplan...       NaN
# 43  NaN                                      To Be Decided       NaN
# 44  NaN                                 Existing to Remove       NaN
#
# 7                               Botanical Name  \
# 0                                          NaN
# 1                                          NaN
# 2              Chamaecyparis obtusa 'Gracilis'
# 3                  Thuja plicata 'Green Giant'
# 4                                          NaN
# 5                     Cornus alba 'Ivory Halo'
# 6                  Fothergilla major ‘Mt Airy’
# 7                         Hamamelis Virginiana
# 8    Hydrangea arborescens 'Incrediball Blush'
# 9             Hydrangea paniculata 'Limelight'
# 10       Hydrangea quercifolia 'Ruby Slippers'
# 11                      Ilex glabra 'Compacta'
# 12                      Ilex glabra 'Compacta'
# 13             Pieris japonica 'Mountain Fire'
# 14             Pieris japonica 'Mountain Fire'
# 15                 Pieris x 'Brouwer's Beauty'
# 16                Rhododendron 'Percy Wiseman'
# 17                          Rhododendron 'PJM'
# 18               Rhododendron maximum 'Roseum'
# 19       Viburnum plicatum tomentosum 'Shasta'
# 20               Viburnum trilobum ‘Compactum'
# 21                                         NaN
# 22                 Actaea simplex ‘Chocoholic'
# 23                Dianthus plumarius ‘Magenta’
# 24     Aster oblongigolius ‘Raydon’s Favorite'
# 25           Brunnera macrophylla 'Jack Frost'
# 26                        Dicentra spectabilis
# 27                        Geranium x 'Rozanne'
# 28  Helleborus orientalis ‘White’ & ‘Champion’
# 29                           Hosta ‘Guacamole'
# 30                        Hosta x 'Blue Angel'
# 31                Iris germanica 'Immortality'
# 32                      Nepeta ‘Purrsian Blue’
# 33                       Paeonia x 'Bartzella'
# 34                         Sedum 'Dazzleberry'
# 35       Tiarella cordifolia ‘Sugar and Spice’
# 36                                         NaN
# 37         Dryopteris erythrosora 'Brilliance'
# 38                                         NaN
# 39  Calamagrostis x acutiflora 'Karl Foerster'
# 40     Pennisetum alopecuriodes ‘Little Bunny’
# 41                                         NaN
# 42                                         NaN
# 43                                         NaN
# 44                                         NaN
#
# 7                           Common Name   Spacing Scheduled Size Remarks
# 0                                   NaN       NaN            NaN     NaN
# 1                                   NaN       NaN            NaN     NaN
# 2          Slender Hinoki False Cypress       NaN         7 - 8'     NaN
# 3                Green Giant Arborvitae       NaN    8 - 10’ B&B     NaN
# 4                                   NaN       NaN            NaN     NaN
# 5                    Ivory Halo Dogwood       NaN         #5 pot     NaN
# 6                  Mt. Airy Fothergilla       NaN         #5 pot     NaN
# 7                      Common Withhazel       NaN       3-4' B&B     NaN
# 8   Incrediball® Blush Smooth Hydrangea       NaN         #7 pot     NaN
# 9             Limelight Hardy Hydrangea       NaN         #7 pot     NaN
# 10     Ruby Slippers Oak Leaf Hydrangea       NaN         #3 pot     NaN
# 11               Compact Inkberry Holly       NaN            #10     Sub
# 12               Compact Inkberry Holly       NaN            #10     Sub
# 13              Mountain Fire Andromeda       NaN       3-4' ht.     NaN
# 14              Mountain Fire Andromeda       NaN       3-4' ht.     NaN
# 15           Brouwer's Beauty Andromeda       NaN            #15     Sub
# 16           Percy Wiseman Rhododendron       NaN             #6     Sub
# 17                     PJM Rhododendron       NaN         #5 pot     NaN
# 18          English Roseum Rhododendron       NaN       3-4' B&B     NaN
# 19                      Shasta Viburnum       NaN       4-5’ ht.     NaN
# 20    Compactum Cranberry Bush Viburnum       NaN         #5 pot     NaN
# 21                                  NaN       NaN            NaN     NaN
# 22                         Fairy Candle  24" o.c.         1 gal.    6-PK
# 23                             Dianthus  18" o.c.         1 gal.     NaN
# 24              Raydon’s Favorite Aster  24" o.c.         1 gal.    6-PK
# 25          Jack Frost Siberian Bugloss  18" o.c.         1 gal.    6-PK
# 26                       Bleeding Heart  18" o.c.         1 gal.    6-PK
# 27                   Rozanne Cranesbill  24" o.c.         1 gal.    6-PK
# 28                          Lenten Rose  24" o.c.         1 gal.    6-PK
# 29              Guacamole Plantain Lily  36" o.c.         2 gal.     NaN
# 30             Blue Angel Plantain Lily  36" o.c.         2 gal.     NaN
# 31             Immortality Bearded Iris  24" o.c.         1 gal.    6-PK
# 32                Purrsian Blue Catmint  24" o.c.         1 gal.     NaN
# 33                 Bartzella Itoh Peony  36" o.c.         #3 pot     NaN
# 34                Dazzleberry Stonecrop  18" o.c.         1 gal.    6-PK
# 35          Sugar and Spice’ Foamflower  18" o.c.         1 gal.    6-PK
# 36                                  NaN       NaN            NaN     NaN
# 37               Brilliance Autumn Fern  18" o.c.             #1    6-PK
# 38                                  NaN       NaN            NaN     NaN
# 39        Foerster's Feather Reed Grass  36" o.c.         2 gal.     NaN
# 40    Little Bunny Dwarf Fountain Grass  18" o.c.         1 gal.     NaN
# 41                                  NaN       NaN            NaN     NaN
# 42                                  NaN       NaN            NaN     NaN
# 43                                  NaN       NaN            NaN     NaN
# 44                                  NaN       NaN            NaN     NaN

# %%
plant_groups_wIDX
# Out:
# {'Deciduous Trees': 0,
#  'Conifers': 1,
#  'Shrubs': 4,
#  'Perennials': 21,
#  'FERNS': 36,
#  'Ornamental Grasses': 38}

# %%
plant_groups_wID
# Out:
# {'Deciduous Trees': [],
#  'Conifers': ['CH OB G', 'TH PL GG'],
#  'Shrubs': ['CO AL IH',
#   'FO MA MA',
#   'HA VA',
#   'HY AR IB',
#   'HY PA LI',
#   'HY QU RS',
#   'IL GL C',
#   'IL GL C',
#   'PI MF',
#   'PI MF',
#   'PI BB',
#   'RH PW',
#   'RH P',
#   'RH MA RO',
#   'VI PL S',
#   'VI TR W'],
#  'Perennials': ['Act B',
#   'Dia M',
#   'Ast VD',
#   'Bru JF',
#   'Dic e',
#   'Ger R',
#   'Hel B',
#   'Hos G',
#   'Hos BA',
#   'Iri I',
#   'Nep PB',
#   'Pae IB',
#   'Sed D',
#   'Tia RT'],
#  'FERNS': ['Dry B'],
#  'Ornamental Grasses': ['Cal KF', 'Pen LB-1']}

# %%
# ensuring all the plant images are jpeg

image_dir = '../inputs/plant_images'
# Loop over the flower images
for filename in os.listdir(image_dir):
    # Check for .jfif file
    if filename.endswith('.jfif'):
        # Open the image
        img = Image.open(os.path.join(image_dir, filename))
        # Save the image as a .jpg file
        base_filename = os.path.splitext(filename)[0]  # Get filename without extension
        img.save(os.path.join(image_dir, base_filename + '.jpg'), 'JPEG') # convert to jpeg
        os.remove(os.path.join(image_dir, filename)) # delete .jfif after

# %%
# grab the file path of each image based on the lists in plant_groups_wID dict

# combine all lists into one for quick test
test_list_all = []
for i in keys_list:
    for item in plant_groups_wID[i]:
        test_list_all.append(item)

# %%
# check if any of of the file paths in the plant_images folder matches each item in test_list_all
has_match = []
matching_path = []
for ID in test_list_all:
    for filename in os.listdir(image_dir):
        if ID in filename:
            has_match.append(ID)
            matching_path.append(filename)

# %%
unique_matches = list(set(has_match))
len(unique_matches)
# Out:
# 28

# %%
len(test_list_all)
# Out:
# 35

# %%
def find_missing_values(list1, list2):
    missing_values = [value for value in list1 if value not in list2]
    return missing_values

# %%
# len(missing_values) != len(test_list_all) - len(unique_matches); this is b/c...
# unique_matches is missing one 'IL GL C' because it was a duplicate that had a file path match
# when list(set(has_match)) happens, it takes away all duplicates
missing_values = find_missing_values(test_list_all, unique_matches)
print(missing_values)
# Out:
# ['HA VA', 'HY PA LI', 'PI MF', 'PI MF', 'Dia M', 'Pen LB-1']

# %%
# TODO - ask mom about missing/misnamed ID values
#      - associate each item in test_list_all with a picture
#      - OR associate each using 4 different lists to keep goups seperate
#      - create docx file with each picutre/caption
#      - streamlit time for bruhx

# %%
has_match
# Out:
# ['CH OB G',
#  'CH OB G',
#  'CH OB G',
#  'TH PL GG',
#  'TH PL GG',
#  'CO AL IH',
#  'FO MA MA',
#  'HY AR IB',
#  'HY AR IB',
#  'HY AR IB',
#  'HY QU RS',
#  'HY QU RS',
#  'IL GL C',
#  'IL GL C',
#  'IL GL C',
#  'IL GL C',
#  'PI BB',
#  'RH PW',
#  'RH P',
#  'RH P',
#  'RH P',
#  'RH P',
#  'RH P',
#  'RH P',
#  'RH P',
#  'RH P',
#  'RH MA RO',
#  'RH MA RO',
#  'VI PL S',
#  'VI PL S',
#  'VI PL S',
#  'VI TR W',
#  'VI TR W',
#  'Act B',
#  'Act B',
#  'Ast VD',
#  'Bru JF',
#  'Dic e',
#  'Ger R',
#  'Hel B',
#  'Hos G',
#  'Hos G',
#  'Hos G',
#  'Hos G',
#  'Hos BA',
#  'Iri I',
#  'Nep PB',
#  'Pae IB',
#  'Sed D',
#  'Sed D',
#  'Tia RT',
#  'Tia RT',
#  'Dry B',
#  'Dry B',
#  'Cal KF',
#  'Cal KF']

# %%
unique_matches
# Out:
# ['TH PL GG',
#  'CO AL IH',
#  'IL GL C',
#  'Pae IB',
#  'FO MA MA',
#  'Bru JF',
#  'VI TR W',
#  'Ger R',
#  'Hos G',
#  'RH P',
#  'Ast VD',
#  'Hos BA',
#  'HY QU RS',
#  'RH PW',
#  'Sed D',
#  'PI BB',
#  'Dry B',
#  'RH MA RO',
#  'VI PL S',
#  'Act B',
#  'Nep PB',
#  'Dic e',
#  'HY AR IB',
#  'Cal KF',
#  'Iri I',
#  'CH OB G',
#  'Tia RT',
#  'Hel B']

# %%
test_list_all.sort()
test_list_all
# Out:
# ['Act B',
#  'Ast VD',
#  'Bru JF',
#  'CH OB G',
#  'CO AL IH',
#  'Cal KF',
#  'Dia M',
#  'Dic e',
#  'Dry B',
#  'FO MA MA',
#  'Ger R',
#  'HA VA',
#  'HY AR IB',
#  'HY PA LI',
#  'HY QU RS',
#  'Hel B',
#  'Hos BA',
#  'Hos G',
#  'IL GL C',
#  'IL GL C',
#  'Iri I',
#  'Nep PB',
#  'PI BB',
#  'PI MF',
#  'PI MF',
#  'Pae IB',
#  'Pen LB-1',
#  'RH MA RO',
#  'RH P',
#  'RH PW',
#  'Sed D',
#  'TH PL GG',
#  'Tia RT',
#  'VI PL S',
#  'VI TR W']

# %%
# create a function that takes a list of plant IDs and returns a dictionary of the plant ID and its image path
def get_image_paths(list_of_plant_IDs):
    image_dir = '../inputs/plant_images'
    plant_IDs_wIMG = {}
    for ID in list_of_plant_IDs:
        for filename in os.listdir(image_dir):
            if ID in filename:
                plant_IDs_wIMG[ID] = os.path.join(image_dir, filename)
    return plant_IDs_wIMG

# %%
test_all_wPicture = get_image_paths(test_list_all)

# %%
len(test_all_wPicture)
# Out:
# 28

# %%
test_all_wPicture
# Out:
# {'Act B': '../inputs/plant_images\\Act BN.jpg',
#  'Ast VD': '../inputs/plant_images\\Ast VD.jpg',
#  'Bru JF': '../inputs/plant_images\\Bru JF.jpg',
#  'CH OB G': '../inputs/plant_images\\CH OB GF.jpg',
#  'CO AL IH': '../inputs/plant_images\\CO AL IH.jpg',
#  'Cal KF': '../inputs/plant_images\\Cal KF.jpg',
#  'Dic e': '../inputs/plant_images\\Dic e.jpg',
#  'Dry B': '../inputs/plant_images\\Dry B.jpg',
#  'FO MA MA': '../inputs/plant_images\\FO MA MA.jpg',
#  'Ger R': '../inputs/plant_images\\Ger R wall.jpg',
#  'HY AR IB': '../inputs/plant_images\\HY AR IB.jpg',
#  'HY QU RS': '../inputs/plant_images\\HY QU RS Ruby Slippers.jpeg',
#  'Hel B': '../inputs/plant_images\\Hel B.jpg',
#  'Hos BA': '../inputs/plant_images\\Hos BA.jpg',
#  'Hos G': '../inputs/plant_images\\Hos GT.jpg',
#  'IL GL C': '../inputs/plant_images\\IL GL C.png',
#  'Iri I': '../inputs/plant_images\\Iri I.jpg',
#  'Nep PB': '../inputs/plant_images\\Nep PB.jpg',
#  'PI BB': '../inputs/plant_images\\PI BB.jpg',
#  'Pae IB': '../inputs/plant_images\\Pae IB.jpg',
#  'RH MA RO': '../inputs/plant_images\\RH MA RO.jpg',
#  'RH P': '../inputs/plant_images\\RH PW.jpg',
#  'RH PW': '../inputs/plant_images\\RH PW.jpg',
#  'Sed D': '../inputs/plant_images\\Sed DB.jpg',
#  'TH PL GG': '../inputs/plant_images\\TH PL GG.jpg',
#  'Tia RT': '../inputs/plant_images\\Tia RT.jpg',
#  'VI PL S': '../inputs/plant_images\\VI PL S.jpg',
#  'VI TR W': '../inputs/plant_images\\VI TR W.jpeg'}

# %%
from PIL import Image, ImageDraw, ImageFont

def create_collage(dictionary, collage_width, image_width):
    images = []
    max_height = 0

    for key in dictionary:
        img = Image.open(dictionary[key])
        wpercent = (image_width / float(img.size[0]))
        hsize = int((float(img.size[1]) * float(wpercent)))
        img = img.resize((image_width, hsize), Image.ANTIALIAS)
        
        draw = ImageDraw.Draw(img)
        text = key
        # Use a truetype font for better quality text
        font = ImageFont.truetype("arial.ttf", 15)
        draw.text((0, 0), text, font=font)  

        images.append(img)
        if img.height > max_height:
            max_height = img.height

    total_height = max_height * (len(images) // (collage_width // image_width) + 1)
    collage = Image.new('RGB', (collage_width, total_height))

    x_offset = 0
    y_offset = 0
    for img in images:
        collage.paste(img, (x_offset, y_offset))
        x_offset += img.width
        if x_offset >= collage_width:
            x_offset = 0
            y_offset += max_height

    collage.show()

# %%
create_collage(test_all_wPicture, 1000, 400)
# Out:
# C:\Users\dbawa\AppData\Local\Temp\ipykernel_4588\2559516585.py:11: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize((image_width, hsize), Image.ANTIALIAS)

# %%
from docx import Document
from docx.shared import Inches

def create_docx(plant_images):
    # Create a new Word document
    document = Document()

    # Loop through the plant images dictionary
    for plant_id, image_path in plant_images.items():
        # Add a new paragraph to the document
        paragraph = document.add_paragraph()

        # Add the plant ID as a bolded caption
        caption = paragraph.add_run(f"{plant_id}: ")
        caption.bold = True

        # Add the image to the paragraph with the appropriate size
        image = document.add_picture(image_path, width=Inches(6))
        # Add a new line after the image
        paragraph.add_run("\n")

    # Save the document to a file
    document.save("test_output/plant_images.docx")

# %%
create_docx(test_all_wPicture)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 create_docx(test_all_wPicture)
#
# Cell In[34], line 18, in create_docx(plant_images)
#      15 caption.bold = True
#      17 # Add the image to the paragraph with the appropriate size
# ---> 18 image = document.add_picture(image_path, width=Inches(6))
#      19 # Add a new line after the image
#      20 paragraph.add_run("\n")
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\document.py:72, in Document.add_picture(self, image_path_or_stream, width, height)
#      59 """
#      60 Return a new picture shape added in its own paragraph at the end of
#      61 the document. The picture contains the image at
#    (...)
#      69 is often the case.
#      70 """
#      71 run = self.add_paragraph().add_run()
# ---> 72 return run.add_picture(image_path_or_stream, width, height)
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\text\run.py:62, in Run.add_picture(self, image_path_or_stream, width, height)
#      49 def add_picture(self, image_path_or_stream, width=None, height=None):
#      50     """
#      51     Return an |InlineShape| instance containing the image identified by
#      52     *image_path_or_stream*, added to the end of this run.
#    (...)
#      60     value is specified, as is often the case.
#      61     """
# ---> 62     inline = self.part.new_pic_inline(image_path_or_stream, width, height)
#      63     self._r.add_drawing(inline)
#      64     return InlineShape(inline)
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\parts\story.py:56, in BaseStoryPart.new_pic_inline(self, image_descriptor, width, height)
#      50 def new_pic_inline(self, image_descriptor, width, height):
#      51     """Return a newly-created `w:inline` element.
#      52
#      53     The element contains the image specified by *image_descriptor* and is scaled
#      54     based on the values of *width* and *height*.
#      55     """
# ---> 56     rId, image = self.get_or_add_image(image_descriptor)
#      57     cx, cy = image.scaled_dimensions(width, height)
#      58     shape_id, filename = self.next_id, image.filename
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\parts\story.py:29, in BaseStoryPart.get_or_add_image(self, image_descriptor)
#      21 def get_or_add_image(self, image_descriptor):
#      22     """Return (rId, image) pair for image identified by *image_descriptor*.
#      23
#      24     *rId* is the str key (often like "rId7") for the relationship between this story
#    (...)
#      27     such as dimensions and image type.
#      28     """
# ---> 29     image_part = self._package.get_or_add_image_part(image_descriptor)
#      30     rId = self.relate_to(image_part, RT.IMAGE)
#      31     return rId, image_part.image
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\package.py:31, in Package.get_or_add_image_part(self, image_descriptor)
#      25 def get_or_add_image_part(self, image_descriptor):
#      26     """Return |ImagePart| containing image specified by *image_descriptor*.
#      27
#      28     The image-part is newly created if a matching one is not already present in the
#      29     collection.
#      30     """
# ---> 31     return self.image_parts.get_or_add_image_part(image_descriptor)
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\package.py:74, in ImageParts.get_or_add_image_part(self, image_descriptor)
#      68 def get_or_add_image_part(self, image_descriptor):
#      69     """Return |ImagePart| object containing image identified by *image_descriptor*.
#      70
#      71     The image-part is newly created if a matching one is not present in the
#      72     collection.
#      73     """
# ---> 74     image = Image.from_file(image_descriptor)
#      75     matching_image_part = self._get_by_sha1(image.sha1)
#      76     if matching_image_part is not None:
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\image\image.py:55, in Image.from_file(cls, image_descriptor)
#      53     blob = stream.read()
#      54     filename = None
# ---> 55 return cls._from_stream(stream, blob, filename)
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\image\image.py:176, in Image._from_stream(cls, stream, blob, filename)
#     170 @classmethod
#     171 def _from_stream(cls, stream, blob, filename=None):
#     172     """
#     173     Return an instance of the |Image| subclass corresponding to the
#     174     format of the image in *stream*.
#     175     """
# --> 176     image_header = _ImageHeaderFactory(stream)
#     177     if filename is None:
#     178         filename = 'image.%s' % image_header.default_ext
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\image\image.py:198, in _ImageHeaderFactory(stream)
#     196     found_bytes = header[offset:end]
#     197     if found_bytes == signature_bytes:
# --> 198         return cls.from_stream(stream)
#     199 raise UnrecognizedImageError
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\image\jpeg.py:68, in Jfif.from_stream(cls, stream)
#      62 @classmethod
#      63 def from_stream(cls, stream):
#      64     """
#      65     Return a |Jfif| instance having header properties parsed from image
#      66     in *stream*.
#      67     """
# ---> 68     markers = _JfifMarkers.from_stream(stream)
#      70     px_width = markers.sof.px_width
#      71     px_height = markers.sof.px_height
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\image\jpeg.py:111, in _JfifMarkers.from_stream(cls, stream)
#     109 marker_parser = _MarkerParser.from_stream(stream)
#     110 markers = []
# --> 111 for marker in marker_parser.iter_markers():
#     112     markers.append(marker)
#     113     if marker.marker_code == JPEG_MARKER_CODE.SOS:
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\image\jpeg.py:176, in _MarkerParser.iter_markers(self)
#     174 while marker_code != JPEG_MARKER_CODE.EOI:
#     175     marker_code, segment_offset = marker_finder.next(start)
# --> 176     marker = _MarkerFactory(
#     177         marker_code, self._stream, segment_offset
#     178     )
#     179     yield marker
#     180     start = segment_offset + marker.segment_length
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\image\jpeg.py:271, in _MarkerFactory(marker_code, stream, offset)
#     269 else:
#     270     marker_cls = _Marker
# --> 271 return marker_cls.from_stream(stream, marker_code, offset)
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\image\jpeg.py:413, in _App1Marker.from_stream(cls, stream, marker_code, offset)
#     411 if cls._is_non_Exif_APP1_segment(stream, offset):
#     412     return cls(marker_code, offset, segment_length, 72, 72)
# --> 413 tiff = cls._tiff_from_exif_segment(stream, offset, segment_length)
#     414 return cls(
#     415     marker_code, offset, segment_length, tiff.horz_dpi, tiff.vert_dpi
#     416 )
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\image\jpeg.py:455, in _App1Marker._tiff_from_exif_segment(cls, stream, offset, segment_length)
#     453 segment_bytes = stream.read(segment_length-8)
#     454 substream = BytesIO(segment_bytes)
# --> 455 return Tiff.from_stream(substream)
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\image\tiff.py:36, in Tiff.from_stream(cls, stream)
#      30 @classmethod
#      31 def from_stream(cls, stream):
#      32     """
#      33     Return a |Tiff| instance containing the properties of the TIFF image
#      34     in *stream*.
#      35     """
# ---> 36     parser = _TiffParser.parse(stream)
#      38     px_width = parser.px_width
#      39     px_height = parser.px_height
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\image\tiff.py:63, in _TiffParser.parse(cls, stream)
#      61 stream_rdr = cls._make_stream_reader(stream)
#      62 ifd0_offset = stream_rdr.read_long(4)
# ---> 63 ifd_entries = _IfdEntries.from_stream(stream_rdr, ifd0_offset)
#      64 return cls(ifd_entries)
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\image\tiff.py:176, in _IfdEntries.from_stream(cls, stream, offset)
#     171 """
#     172 Return a new |_IfdEntries| instance parsed from *stream* starting at
#     173 *offset*.
#     174 """
#     175 ifd_parser = _IfdParser(stream, offset)
# --> 176 entries = dict((e.tag, e.value) for e in ifd_parser.iter_entries())
#     177 return cls(entries)
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\image\tiff.py:176, in <genexpr>(.0)
#     171 """
#     172 Return a new |_IfdEntries| instance parsed from *stream* starting at
#     173 *offset*.
#     174 """
#     175 ifd_parser = _IfdParser(stream, offset)
# --> 176 entries = dict((e.tag, e.value) for e in ifd_parser.iter_entries())
#     177 return cls(entries)
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\image\tiff.py:204, in _IfdParser.iter_entries(self)
#     202 for idx in range(self._entry_count):
#     203     dir_entry_offset = self._offset + 2 + (idx*12)
# --> 204     ifd_entry = _IfdEntryFactory(self._stream_rdr, dir_entry_offset)
#     205     yield ifd_entry
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\image\tiff.py:231, in _IfdEntryFactory(stream_rdr, offset)
#     229 else:
#     230     entry_cls = _IfdEntry
# --> 231 return entry_cls.from_stream(stream_rdr, offset)
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\image\tiff.py:255, in _IfdEntry.from_stream(cls, stream_rdr, offset)
#     253 value_count = stream_rdr.read_long(offset, 4)
#     254 value_offset = stream_rdr.read_long(offset, 8)
# --> 255 value = cls._parse_value(
#     256     stream_rdr, offset, value_count, value_offset
#     257 )
#     258 return cls(tag_code, value)
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\image\tiff.py:294, in _AsciiIfdEntry._parse_value(cls, stream_rdr, offset, value_count, value_offset)
#     287 @classmethod
#     288 def _parse_value(cls, stream_rdr, offset, value_count, value_offset):
#     289     """
#     290     Return the ASCII string parsed from *stream_rdr* at *value_offset*.
#     291     The length of the string, including a terminating '\x00' (NUL)
#     292     character, is in *value_count*.
#     293     """
# --> 294     return stream_rdr.read_str(value_count-1, value_offset)
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\image\helpers.py:69, in StreamReader.read_str(self, char_count, base, offset)
#      67     format_ = '%ds' % char_count
#      68     return Struct(format_)
# ---> 69 struct = str_struct(char_count)
#      70 chars = self._unpack_item(struct, base, offset)
#      71 unicode_str = chars.decode('UTF-8')
#
# File c:\Users\dbawa\anaconda3\lib\site-packages\docx\image\helpers.py:68, in StreamReader.read_str.<locals>.str_struct(char_count)
#      66 def str_struct(char_count):
#      67     format_ = '%ds' % char_count
# ---> 68     return Struct(format_)
#
# error: bad char in struct format
